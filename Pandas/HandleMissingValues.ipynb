# %%
import pandas as pd
import numpy as np

people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'],
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'],
    'email': [
        'CoreyMSchafer@gmail.com',
        'JaneDoe@email.com',
        'JohnDoe@email.com',
        None,
        np.nan,
        'Anonymous@email.com',
        'NA'
    ],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

df = pd.DataFrame(people)
df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)

df
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@email.com   55
# 2   John      Doe        JohnDoe@email.com   63
# 3  Chris  Schafer                      NaN   36
# 4    NaN      NaN                      NaN  NaN
# 5    NaN      NaN      Anonymous@email.com  NaN
# 6    NaN      NaN                      NaN  NaN

# %%
df.dropna() #drops NaN values (except custom missing values at last)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df.dropna(axis='index',how='all') # how -> any means '|' and all means '&'
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@email.com   55
# 2   John      Doe        JohnDoe@email.com   63
# 3  Chris  Schafer                      NaN   36
# 5    NaN      NaN      Anonymous@email.com  NaN

# %%
df.dropna(axis='columns',how='all')
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@email.com   55
# 2   John      Doe        JohnDoe@email.com   63
# 3  Chris  Schafer                      NaN   36
# 4    NaN      NaN                      NaN  NaN
# 5    NaN      NaN      Anonymous@email.com  NaN
# 6    NaN      NaN                      NaN  NaN

# %%
df.dropna(axis='index',how='any', subset = ['email'])
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@email.com   55
# 2   John      Doe        JohnDoe@email.com   63
# 5    NaN      NaN      Anonymous@email.com  NaN

# %%
df.isna() #mask for NaN values
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna('MISSING!')
# Out:
#       first      last                    email       age
# 0     Corey   Schafer  CoreyMSchafer@gmail.com        33
# 1      Jane       Doe        JaneDoe@email.com        55
# 2      John       Doe        JohnDoe@email.com        63
# 3     Chris   Schafer                 MISSING!        36
# 4  MISSING!  MISSING!                 MISSING!  MISSING!
# 5  MISSING!  MISSING!      Anonymous@email.com  MISSING!
# 6  MISSING!  MISSING!                 MISSING!  MISSING!

# %%
df.dtypes
# Out:
# first    str
# last     str
# email    str
# age      str
# dtype: object

# %%
# When we have NaN values in a series which needs to be str->int, use float as NaN-> Float under the hood

# %%
type(np.nan)
# Out:
# float

# %%
# df['age'] = df['age'].astype(int) casts str to int but will not work here due to reason above

# %%
df['age'] = df['age'].astype(float)

# %%
df.dtypes
# Out:
# first        str
# last         str
# email        str
# age      float64
# dtype: object

# %%
df['age'].mean()
# Out:
# np.float64(46.75)

# %%
 # df.astype() for casting whole df
