# %%
import pandas as pd

# %%
na_vals = ['Na', 'Missing'] #list for NaN values errors
df = pd.read_csv('results.csv', index_col = 'Respondent',na_values = na_vals) #new index

# %%
pd.set_option('display.max_rows',85)

# %%
pd.set_option('display.max_columns',85)

# %%
schema_df = pd.read_csv('schema.csv', index_col = 'Column') #new index

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.loc[1]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %%
schema_df.loc['Respondent', 'QuestionText']
# Out:
# 'Randomized respondent ID number (not in order of survey response time)'

# %%
schema_df.sort_index(inplace = True) #sort indexes alphabetically (for reverse pass in ascending = False)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
high_salary = (df['ConvertedComp'] > 10000)

# %%
df.loc[high_salary, 'Country']
# Out:
# Respondent
# 4        United States
# 6               Canada
# 9          New Zealand
# 10               India
# 13       United States
#              ...
# 88878    United States
# 88879          Finland
# 88881          Austria
# 88882      Netherlands
# 88883           Greece
# Name: Country, Length: 50029, dtype: str

# %%
countries = ['India']
filte = df['Country'].isin(countries)

# %%
df.loc[filte, 'Country']
# Out:
# Respondent
# 8        India
# 10       India
# 15       India
# 50       India
# 65       India
#          ...
# 77339    India
# 79795    India
# 83862    India
# 84299    India
# 86012    India
# Name: Country, Length: 9061, dtype: str

# %%
lang_fil = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[lang_fil, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: str

# %%
df.rename(columns={'ConvertedComp': 'SalaryISD'}, inplace = True)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['Hobbyist'].map({'Yes': True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})

# %%
df.head()
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.sort_values(by = 'Country', inplace = True)

# %%
df.head()
# Out:
#                                 MainBranch  Hobbyist              OpenSourcer  \
# Respondent
# 39258       I am a developer by profession      True  Less than once per year
# 63129       I am a developer by profession      True                    Never
# 85715       I am a developer by profession     False  Less than once per year
# 50767       I am a developer by profession     False  Less than once per year
# 2782                                   NaN      True  Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 39258       OSS is, on average, of LOWER quality than prop...
# 63129       OSS is, on average, of HIGHER quality than pro...
# 85715       The quality of OSS and closed source software ...
# 50767                                                     NaN
# 2782        OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment      Country  \
# Respondent
# ...

# %%
df[['Country', 'SalaryISD']].head()
# Out:
#                 Country  SalaryISD
# Respondent
# 39258       Afghanistan    19152.0
# 63129       Afghanistan  1000000.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN

# %%
df.sort_values(by = ['Country', 'SalaryISD'], inplace = True, ascending = [True,False])

# %%
df[['Country', 'SalaryISD']].head()
# Out:
#                 Country  SalaryISD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0

# %%
df['SalaryISD'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryISD, dtype: float64

# %%
df.nlargest(10, 'SalaryISD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      True
# 87896                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 78151                          I am a developer by profession      True
# 80200                          I am a developer by profession      True
# 52132                          I am a developer by profession      True
# 75561                          I am a developer by profession      True
# 32250                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
#Aggergation - Combining multiple pieces of data

# %%
df['SalaryISD'].head(15)
# Out:
# Respondent
# 63129    1000000.0
# 50499     153216.0
# 39258      19152.0
# 58450      17556.0
# 7085       14364.0
# 22450       7980.0
# 48436       4464.0
# 10746       3996.0
# 8149        1596.0
# 29736       1116.0
# 28638          0.0
# 722            0.0
# 85715          NaN
# 50767          NaN
# 2782           NaN
# Name: SalaryISD, dtype: float64

# %%
df['SalaryISD'].median()
# Out:
# np.float64(57287.0)

# %%
df.median(numeric_only=True)
# Out:
# Hobbyist           1.0
# CompTotal      62000.0
# SalaryISD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe() #describes briefly the df and count -> no. of non NaN rows
# Out:
#           CompTotal     SalaryISD   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %%
#We use median instead of mean to avoid outliers confusion

# %%
df['SalaryISD'].count() #gives total non-NaN data in column
# Out:
# np.int64(55823)

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# True     71257
# False    17626
# Name: count, dtype: int64

# %%
df['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: str

# %%
df['SocialMedia'].value_counts(normalize = True) #percentages
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Saint Kitts and Nevis                   1
# Saint Vincent and the Grenadines        1
# Sao Tome and Principe                   1
# Timor-Leste                             1
# Tonga                                   1
# Name: count, Length: 179, dtype: int64

# %%
# group_by = split_object + combine_column + show_results

# %%
country_grp = df.groupby(['Country']) #df obj of Country

# %%
country_grp = df.groupby('Country')

# %%
country_grp.get_group('India')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 80923                          I am a developer by profession      True
# 78265                          I am a developer by profession      True
# ...                                                       ...       ...
# 79312                  I am a student who is learning to code      True
# 79628                          I am a developer by profession     False
# 40151                                                     NaN     False
# 76400       I am not primarily a developer, but I write co...     False
# 30452                  I am a student who is learning to code     False
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt]['SocialMedia'].value_counts() #filter + function (combining done by grp_by)
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# WeChat 微信                      5
# Hello                          5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['United States']
# Out:
# SocialMedia
# Reddit                      0.284346
# Twitter                     0.173002
# Facebook                    0.141874
# YouTube                     0.122867
# I don't use social media    0.092338
# Instagram                   0.082410
# LinkedIn                    0.050883
# WhatsApp                    0.030380
# Snapchat                    0.016263
# WeChat 微信                   0.004639
# VK ВКонта́кте               0.000449
# Weibo 新浪微博                  0.000399
# Hello                       0.000100
# Youku Tudou 优酷              0.000050
# Name: proportion, dtype: float64

# %%
country_grp['SalaryISD'].median().loc['Germany']
# Out:
# np.float64(63016.0)

# %%
country_grp['SalaryISD'].agg(['median', 'mean']).loc['India'] #multiple aggregate functions
# Out:
# median    10080.000000
# mean      28057.664916
# Name: India, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# np.int64(3105)

# %%
#sum works on both numeric and boolean data

# %%
# country_grp['LanguageWorkedWith'].str.contains('Python').sum()

# %%
#Above one does not work as str does not work on series grp by obj (so apply func)

# %%
country_grp['LanguageWorkedWith'].apply(
    lambda x: x.str.contains('Python', na=False).sum()
)                                     #obj->str
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_resp = df['Country'].value_counts()
country_resp
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Saint Kitts and Nevis                   1
# Saint Vincent and the Grenadines        1
# Sao Tome and Principe                   1
# Timor-Leste                             1
# Tonga                                   1
# Name: count, Length: 179, dtype: int64

# %%
country_python = country_grp['LanguageWorkedWith'].apply(
    lambda x: x.str.contains('Python', na=False).sum()
)

# %%
country_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_resp,country_python], axis = 'columns', sort = False)

# %%
python_df.rename(columns={'count': 'NumOfRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace = True)
python_df
# Out:
#                                   NumOfRespondents  NumKnowsPython
# Country
# United States                                20949           10083
# India                                         9061            3105
# Germany                                       5866            2451
# United Kingdom                                5737            2384
# Canada                                        3395            1558
# ...                                            ...             ...
# Saint Kitts and Nevis                            1               0
# Saint Vincent and the Grenadines                 1               0
# Sao Tome and Principe                            1               1
# Timor-Leste                                      1               1
# Tonga                                            1               0
#
# [179 rows x 2 columns]

# %%
python_df['Percentage_knows_python'] = (python_df['NumKnowsPython']/python_df['NumOfRespondents']) * 100

# %%
python_df
# Out:
#                                   NumOfRespondents  NumKnowsPython  \
# Country
# United States                                20949           10083
# India                                         9061            3105
# Germany                                       5866            2451
# United Kingdom                                5737            2384
# Canada                                        3395            1558
# ...                                            ...             ...
# Saint Kitts and Nevis                            1               0
# Saint Vincent and the Grenadines                 1               0
# Sao Tome and Principe                            1               1
# Timor-Leste                                      1               1
# Tonga                                            1               0
#
#                                   Percentage_knows_python
# Country
# United States                                   48.131176
# ...

# %%
python_df.sort_values(by='Percentage_knows_python', ascending = False, inplace= True)
python_df.head(50)
# Out:
#                                   NumOfRespondents  NumKnowsPython  \
# Country
# Timor-Leste                                      1               1
# Sao Tome and Principe                            1               1
# Niger                                            1               1
# Dominica                                         1               1
# Turkmenistan                                     7               6
# Mauritania                                       7               5
# Bahamas                                          3               2
# Guinea                                           3               2
# Guyana                                           3               2
# Uganda                                          72              47
# Iceland                                         49              30
# Namibia                                          5               3
# Haiti                                            5               3
# ...

# %%
python_df.loc['Japan']
# Out:
# NumOfRespondents           391.000000
# NumKnowsPython             182.000000
# Percentage_knows_python     46.547315
# Name: Japan, dtype: float64

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 63129    Less than 1 year
# 50499                   7
# 39258                   2
# 58450                   6
# 7085                    7
# 22450                   3
# 48436                   2
# 10746                   4
# 8149                    2
# 29736                  10
# Name: YearsCode, dtype: str

# %%
# df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].unique()
# Out:
# <StringArray>
# [  'Less than 1 year',                  '7',                  '2',
#                   '6',                  '3',                  '4',
#                  '10',                 '36',                  '8',
#                   nan,                  '1',                 '20',
#                  '28',                 '31',                  '9',
#                   '5', 'More than 50 years',                 '15',
#                  '13',                 '12',                 '17',
#                  '18',                 '35',                 '14',
#                  '21',                 '25',                 '11',
#                  '19',                 '22',                 '23',
#                  '40',                 '39',                 '30',
#                  '43',                 '27',                 '33',
#                  '29',                 '24',                 '34',
#                  '16',                 '26',                 '32',
# ...

# %%
df.replace({
    'YearsCode': {
        'Less than 1 year': 0,
        'More than 50 years': 51
    }
}, inplace=True)
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 63129                          I am a developer by profession      True
# 50499       I am not primarily a developer, but I write co...      True
# 39258                          I am a developer by profession      True
# 58450                          I am a developer by profession      True
# 7085                           I am a developer by profession      True
# ...                                                       ...       ...
# 88062                                                     NaN     False
# 88076                                                     NaN     False
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
#
#                         OpenSourcer  \
# Respondent
# 63129                         Never
# ...

# %%
df['YearsCode'] = (df['YearsCode']).astype(float)

# %%
df['YearsCode'].mean()
# Out:
# np.float64(11.662114216834588)

# %%
df['YearsCode'].median()
# Out:
# np.float64(9.0)

# %%
filtt = (df['Country'] == 'India')
india_df = df.loc[filtt]
india_df.head()
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 80923                          I am a developer by profession      True
# 78265                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 22013                                                   Never
# 28243                              Once a month or more often
# 72732       Less than once a month but more than once per ...
# 80923                              Once a month or more often
# 78265                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
india_df.to_csv('india.csv')

# %%
# tab limited files -> data seperated by tabs not comma like in csv

# %%
india_df.to_csv('india.tsv', sep='\t') #give sep while reading also

# %%
india_df.to_excel('india.xlsx')

# %%
test = pd.read_excel('india.xlsx', index_col = 'Respondent')

# %%
test.head(3)
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
#
#                                                   OpenSourcer  \
# Respondent
# 22013                                                   Never
# 28243                              Once a month or more often
# 72732       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 22013       The quality of OSS and closed source software ...
# 28243       OSS is, on average, of HIGHER quality than pro...
# 72732       OSS is, on average, of LOWER quality than prop...
#
#                                                    Employment Country  \
# Respondent
# ...

# %%
india_df.to_json('india.json')

# %%
india_df.to_json('india_records.json', orient = 'records', lines=True)

# %%
india_json = test = pd.read_json('india.json')
india_json.head()
# Out:
#                                               MainBranch  Hobbyist  \
# 22013                     I am a developer by profession      True
# 28243                     I am a developer by profession      True
# 72732  I am not primarily a developer, but I write co...     False
# 80923                     I am a developer by profession      True
# 78265                     I am a developer by profession      True
#
#                                              OpenSourcer  \
# 22013                                              Never
# 28243                         Once a month or more often
# 72732  Less than once a month but more than once per ...
# 80923                         Once a month or more often
# 78265                         Once a month or more often
#
#                                               OpenSource  \
# 22013  The quality of OSS and closed source software ...
# 28243  OSS is, on average, of HIGHER quality than pro...
# ...

# %%
# sequel alchemy -> very popular ORM (Object Relational Mapper) that helps us to work with more DB's in Python

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://dbuser:dbuser@localhost:5432/sample_db')

# %%
 # india_df.to_sql('sample_table',engine, if_exists='replace'/'error'/'append') [Need PostgrelSQL]

# %%
# sql_df = pd.read_sql('sample_table',engine,index_col='Respondent') [loads SQl -> pd]

# %%
# sql_df = pd.read_sql('SELECT * FROM sample_table',engine,index_col='Respondent')

# %%
posts_df = pd.read_json('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json')

# %%
posts_df.head() #JSON
# Out:
#                           title  \
# 0               My Updated Post
# 1                 A Second Post
# 2  Top 5 Programming Lanaguages
# 3  Sublime Text Tips and Tricks
# 4              Best Python IDEs
#
#                                              content  user_id
# 0    My first updated post!\r\n\r\nThis is exciting!        1
# 1            This is a post from a different user...        2
# 2  Te melius apeirian postulant cum, labitur admo...        1
# 3  Ea vix dico modus voluptatibus, mel iudico sua...        1
# 4  Elit contentiones nam no, sea ut consul adipis...        1
