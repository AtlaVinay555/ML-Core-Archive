# %%
people = {
    "first": ['Corey', 'Jane', 'John'],
    "last": ['Schafer', 'Doe', 'Doe'],
    "email": ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}

import pandas as pd

df = pd.DataFrame(people)

df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.columns = ['f_n','l_n','mail']

# %%
df
# Out:
#      f_n      l_n                     mail
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df
# Out:
#      F_N      L_N                     MAIL
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.rename(columns = {'F_N':'f_n'}, inplace = True)

# %%
df
# Out:
#      f_n      L_N                     MAIL
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[2] = ['John', 'Smith' , 'JohnSmith@gmail.com']

# %%
df
# Out:
#      f_n      L_N                     MAIL
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith      JohnSmith@gmail.com

# %%
df.loc[2, ['f_n']] = ['Jack']

# %%
df
# Out:
#      f_n      L_N                     MAIL first
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   NaN
# 1   Jane      Doe        JaneDoe@email.com   NaN
# 2   Jack    Smith      JohnSmith@gmail.com  Jack

# %%
df.at[2, 'f_n'] = 'James'

# %%
df
# Out:
#      f_n      L_N                     MAIL first
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   NaN
# 1   Jane      Doe        JaneDoe@email.com   NaN
# 2  James    Smith      JohnSmith@gmail.com  Jack

# %%
filt = (df['MAIL'] == 'JaneDoe@email.com')
df[filt]
# Out:
#     f_n  L_N               MAIL first
# 1  Jane  Doe  JaneDoe@email.com   NaN

# %%
filt = (df['MAIL'] == 'JaneDoe@email.com')
df.loc[filt, 'L_N'] = 'Doeee'

# %%
df
# Out:
#      f_n      L_N                     MAIL first
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   NaN
# 1   Jane    Doeee        JaneDoe@email.com   NaN
# 2  James    Smith      JohnSmith@gmail.com  Jack

# %%
df['MAIL'] = df['MAIL'].str.lower()

# %%
df
# Out:
#      f_n      L_N                     MAIL first
# 0  Corey  Schafer  coreymschafer@gmail.com   NaN
# 1   Jane    Doeee        janedoe@email.com   NaN
# 2  James    Smith      johnsmith@gmail.com  Jack

# %%
df['MAIL'].apply(len)
# Out:
# 0    23
# 1    17
# 2    19
# Name: MAIL, dtype: int64

# %%
def return_email(MAIL):
    return MAIL.upper()

# %%
df['MAIL'].apply(return_email)
# Out:
# 0    COREYMSCHAFER@GMAIL.COM
# 1          JANEDOE@EMAIL.COM
# 2        JOHNSMITH@GMAIL.COM
# Name: MAIL, dtype: str

# %%
df['MAIL'] = df['MAIL'].apply(return_email)

# %%
df
# Out:
#      f_n      L_N                     MAIL first
# 0  Corey  Schafer  COREYMSCHAFER@GMAIL.COM   NaN
# 1   Jane    Doeee        JANEDOE@EMAIL.COM   NaN
# 2  James    Smith      JOHNSMITH@GMAIL.COM  Jack

# %%
df['MAIL'] = df['MAIL'].apply(lambda x: x.lower())  #apply on specific series

# %%
df
# Out:
#      f_n      L_N                     MAIL first
# 0  Corey  Schafer  coreymschafer@gmail.com   NaN
# 1   Jane    Doeee        janedoe@email.com   NaN
# 2  James    Smith      johnsmith@gmail.com  Jack

# %%
df.apply(len) #not what we want
# Out:
# f_n      3
# L_N      3
# MAIL     3
# first    3
# dtype: int64

# %%
df.apply(len, axis = 'columns') #apply on whole df
# Out:
# 0    4
# 1    4
# 2    4
# dtype: int64

# %%
df.apply(pd.Series.min) #as strings, aplhabetic order
# Out:
# f_n                        Corey
# L_N                        Doeee
# MAIL     coreymschafer@gmail.com
# first                       Jack
# dtype: str

# %%
df.apply(lambda x: x.min())
# Out:
# f_n                        Corey
# L_N                        Doeee
# MAIL     coreymschafer@gmail.com
# first                       Jack
# dtype: str

# %%
#applymap (deprecated to map) for individual data in df (not series)

# %%
# df.map(len) - needed float values

# %%
df.head()
df.dtypes
# Out:
# f_n      str
# L_N      str
# MAIL     str
# first    str
# dtype: object

# %%
df.drop('first', axis=1, inplace=True)

# %%
df.map(str.lower)
# Out:
#      f_n      L_N                     MAIL
# 0  corey  schafer  coreymschafer@gmail.com
# 1   jane    doeee        janedoe@email.com
# 2  james    smith      johnsmith@gmail.com

# %%
df['L_N'].map({'schafer': 'Shafir','doeee': 'Dovee'})
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# Name: L_N, dtype: str

# %%
#if we do not give any name in above map , then NaN (fixed by replace)

# %%
df['L_N'].replace({'schafer': 'Shafir','doeee': 'Dovee'})
# Out:
# 0    Schafer
# 1      Doeee
# 2      Smith
# Name: L_N, dtype: str

# %%
df['L_N'] = df['L_N'].replace({'schafer': 'Shafir','doeee': 'Dovee'})

# %%
df
# Out:
#      f_n      L_N                     MAIL
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane    Doeee        janedoe@email.com
# 2  James    Smith      johnsmith@gmail.com
