# %%
dict = {
    "names" : ["Vinay","Rahul","Deva","Hemanth","Uddav"]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#    first_name last_name
# 0        Atla     Vinay
# 1     Gunturu     Rahul
# 2  Rachakonda      Deva

# %%
df['names']
df.names

# %%
#df[['column1','column2']] for multi columns

# %%
df.columns
# Out:
# Index(['first_name', 'last_name'], dtype='str')

# %%
df.iloc[0] #rows and same for multi rows as multi-columns above for integer location
# Out:
# first_name     Atla
# last_name     Vinay
# Name: 0, dtype: str

# %%
df.iloc[[0,1],2] # [[r1,r2],c]

# %%
df.loc[0] #row 1 and same as iloc for inner rows and specific columns lists (but in names not int)
# Out:
# first_name     Atla
# last_name     Vinay
# Name: 0, dtype: str
